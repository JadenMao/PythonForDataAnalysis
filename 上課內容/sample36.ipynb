# %%
import numpy as np
import pandas as pd

dataFrame = pd.read_csv('各鄉鎮市區人口密度.csv')
dataFrame
# Out:
#     statistic_yyy                                            site_id  \
# 0             統計年                                                區域別
# 1             106                                             新北市板橋區
# 2             106                                             新北市三重區
# 3             106                                             新北市中和區
# 4             106                                             新北市永和區
# ..            ...                                                ...
# 371           NaN                                                NaN
# 372           NaN                           說明：1.人口密度係指每單位土地面積內之人口數。
# 373           NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)
# 374           NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。
# 375           NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。
#
#     people_total     area population_density
# 0          年底人口數     土地面積               人口密度
# 1         551480  23.1373              23835
# ...

# %%
dataFrame.columns = dataFrame.loc[0]
dataFrame = dataFrame.loc[1:368,]

# %%
dataFrame=dataFrame.reindex(columns=['區域別','年底人口數','土地面積'])

# %%
dataFrame
# Out:
# 0       區域別   年底人口數     土地面積
# 1    新北市板橋區  551480  23.1373
# 2    新北市三重區  387484   16.317
# 3    新北市中和區  413590   20.144
# 4    新北市永和區  222585   5.7138
# 5    新北市新莊區  416524  19.7383
# ..      ...     ...      ...
# 364  金門縣烏坵鄉     685      1.2
# 365  連江縣南竿鄉    7544     10.4
# 366  連江縣北竿鄉    2360      9.9
# 367  連江縣莒光鄉    1624      4.7
# 368  連江縣東引鄉    1352      3.8
#
# [368 rows x 3 columns]

# %%
dataFrame.dtypes
# Out:
# 0
# 區域別      object
# 年底人口數    object
# 土地面積     object
# dtype: object

# %%
dataFrame['年底人口數']=dataFrame['年底人口數'].astype(int)
dataFrame['土地面積']=dataFrame['土地面積'].astype(float)

# %%
dataFrame.dtypes
# Out:
# 0
# 區域別       object
# 年底人口數      int64
# 土地面積     float64
# dtype: object

# %%
dataFrame
# Out:
# 0       區域別   年底人口數     土地面積
# 1    新北市板橋區  551480  23.1373
# 2    新北市三重區  387484  16.3170
# 3    新北市中和區  413590  20.1440
# 4    新北市永和區  222585   5.7138
# 5    新北市新莊區  416524  19.7383
# ..      ...     ...      ...
# 364  金門縣烏坵鄉     685   1.2000
# 365  連江縣南竿鄉    7544  10.4000
# 366  連江縣北竿鄉    2360   9.9000
# 367  連江縣莒光鄉    1624   4.7000
# 368  連江縣東引鄉    1352   3.8000
#
# [368 rows x 3 columns]

# %%
dataFrame['縣市']=dataFrame['區域別'].map(lambda x: x[:3])

# %%
dataFrame[:40]
# Out:
# 0      區域別   年底人口數      土地面積   縣市
# 1   新北市板橋區  551480   23.1373  新北市
# 2   新北市三重區  387484   16.3170  新北市
# 3   新北市中和區  413590   20.1440  新北市
# 4   新北市永和區  222585    5.7138  新北市
# 5   新北市新莊區  416524   19.7383  新北市
# 6   新北市新店區  302089  120.2255  新北市
# 7   新北市樹林區  184149   33.1288  新北市
# 8   新北市鶯歌區   86593   21.1248  新北市
# 9   新北市三峽區  114926  191.4508  新北市
# 10  新北市淡水區  169597   70.6565  新北市
# 11  新北市汐止區  199321   71.2354  新北市
# 12  新北市瑞芳區   40353   70.7336  新北市
# 13  新北市土城區  238067   29.5578  新北市
# 14  新北市蘆洲區  201309    7.4351  新北市
# 15  新北市五股區   84919   34.8632  新北市
# 16  新北市泰山區   78911   19.1603  新北市
# 17  新北市林口區  106101   54.1519  新北市
# 18  新北市深坑區   23660   20.5787  新北市
# 19  新北市石碇區    7683  144.3498  新北市
# 20  新北市坪林區    6528  170.8350  新北市
# 21  新北市三芝區   23200   65.9909  新北市
# 22  新北市石門區   12286   51.2645  新北市
# 23  新北市八里區   38493   39.4933  新北市
# 24  新北市平溪區    4719   71.3382  新北市
# 25  新北市雙溪區    8939  146.2484  新北市
# 26  新北市貢寮區   12552   99.9734  新北市
# ...

# %%
dataFrame.groupby('縣市').sum()
# Out:
# 0      年底人口數       土地面積
# 縣市
# 南投縣   501051  4106.4360
# 嘉義市   269398    60.0256
# 嘉義縣   511182  1903.6367
# 基隆市   371458   132.7589
# 宜蘭縣   456607  2143.6251
# 屏東縣   829939  2775.6003
# 彰化縣  1282458  1074.3960
# 新北市  3986689  2052.5667
# 新竹市   441132   104.1526
# 新竹縣   552169  1427.5369
# 桃園市  2188017  1220.9540
# 澎湖縣   104073   126.8641
# 臺中市  2787070  2214.8968
# 臺北市  2683257   271.7997
# 臺南市  1886522  2191.6531
# 臺東縣   219540  3515.2526
# 花蓮縣   329237  4628.5714
# 苗栗縣   553807  1820.3149
# 連江縣    12880    28.8000
# 金門縣   137456   151.6560
# 雲林縣   690373  1290.8326
# 高雄市  2776912  2951.8524

# %%
import pandas as pd
import numpy as np

result = pd.read_csv('各鄉鎮市區人口密度.csv')
result[30:60]
result
# Out:
#     statistic_yyy                                            site_id  \
# 0             統計年                                                區域別
# 1             106                                             新北市板橋區
# 2             106                                             新北市三重區
# 3             106                                             新北市中和區
# 4             106                                             新北市永和區
# ..            ...                                                ...
# 371           NaN                                                NaN
# 372           NaN                           說明：1.人口密度係指每單位土地面積內之人口數。
# 373           NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)
# 374           NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。
# 375           NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。
#
#     people_total     area population_density
# 0          年底人口數     土地面積               人口密度
# 1         551480  23.1373              23835
# ...

# %%
#計算縣市的人口數
#整理欄位名稱
result.columns=result.loc[0]
result
# Out:
# 0    統計年                                                區域別   年底人口數     土地面積  \
# 0    統計年                                                區域別   年底人口數     土地面積
# 1    106                                             新北市板橋區  551480  23.1373
# 2    106                                             新北市三重區  387484   16.317
# 3    106                                             新北市中和區  413590   20.144
# 4    106                                             新北市永和區  222585   5.7138
# ..   ...                                                ...     ...      ...
# 371  NaN                                                NaN     NaN      NaN
# 372  NaN                           說明：1.人口密度係指每單位土地面積內之人口數。     NaN      NaN
# 373  NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)     NaN      NaN
# 374  NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。     NaN      NaN
# 375  NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。     NaN      NaN
#
# 0     人口密度
# 0     人口密度
# 1    23835
# ...

# %%
result=result.drop(0)

# %%
result
# Out:
# 0    統計年                                                區域別   年底人口數     土地面積  \
# 1    106                                             新北市板橋區  551480  23.1373
# 2    106                                             新北市三重區  387484   16.317
# 3    106                                             新北市中和區  413590   20.144
# 4    106                                             新北市永和區  222585   5.7138
# 5    106                                             新北市新莊區  416524  19.7383
# ..   ...                                                ...     ...      ...
# 371  NaN                                                NaN     NaN      NaN
# 372  NaN                           說明：1.人口密度係指每單位土地面積內之人口數。     NaN      NaN
# 373  NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)     NaN      NaN
# 374  NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。     NaN      NaN
# 375  NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。     NaN      NaN
#
# 0     人口密度
# 1    23835
# 2    23747
# ...

# %%
#整理移除不要的內容
result[-20:]
# Out:
# 0    統計年     區域別   年底人口數     土地面積   人口密度
# 349  106  基隆市暖暖區   38708  22.8283   1696
# 350  106  基隆市仁愛區   44314   4.2335  10467
# 351  106  基隆市中山區   47908  10.5238   4552
# 352  106  基隆市安樂區   82358   18.025   4569
# 353  106  基隆市信義區   52035  10.6706   4876
# 354  106   新竹市東區  212553  33.5768   6330
# 355  106   新竹市北區  150636  15.7267   9578
# 356  106  新竹市香山區   77943  54.8491   1421
# 357  106   嘉義市東區  122103  30.1556   4049
# 358  106   嘉義市西區  147295    29.87   4931
# 359  106  金門縣金城鎮   43285   21.713   1994
# 360  106  金門縣金湖鎮   29413   41.696    705
# 361  106  金門縣金沙鎮   20535    41.19    499
# 362  106  金門縣金寧鄉   30838   29.854   1033
# 363  106  金門縣烈嶼鄉   12700   16.003    794
# 364  106  金門縣烏坵鄉     685      1.2    571
# 365  106  連江縣南竿鄉    7544     10.4    725
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    346
# 368  106  連江縣東引鄉    1352      3.8    356

# %%
result=result.loc[1:368]

# %%
result
# Out:
# 0    統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 364  106  金門縣烏坵鄉     685      1.2    571
# 365  106  連江縣南竿鄉    7544     10.4    725
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    346
# 368  106  連江縣東引鄉    1352      3.8    356
#
# [368 rows x 5 columns]

# %%
result.dtypes
# Out:
# 0
# 統計年      object
# 區域別      object
# 年底人口數    object
# 土地面積     object
# 人口密度     object
# dtype: object

# %%
#改欄位的資料類型
result.iloc[:,2]=result['年底人口數'].astype(int)
result.iloc[:,3]=result['土地面積'].astype(float)
result.iloc[:,4]=result['人口密度'].astype(int)

# %%
result.dtypes
# Out:
# 0
# 統計年       object
# 區域別       object
# 年底人口數      int64
# 土地面積     float64
# 人口密度       int64
# dtype: object

# %%
result
# Out:
# 0    統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484  16.3170  23747
# 3    106  新北市中和區  413590  20.1440  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 364  106  金門縣烏坵鄉     685   1.2000    571
# 365  106  連江縣南竿鄉    7544  10.4000    725
# 366  106  連江縣北竿鄉    2360   9.9000    238
# 367  106  連江縣莒光鄉    1624   4.7000    346
# 368  106  連江縣東引鄉    1352   3.8000    356
#
# [368 rows x 5 columns]

# %%
result=result.reindex(columns=['區域別','年底人口數','土地面積'])
result
# Out:
# 0       區域別   年底人口數     土地面積
# 1    新北市板橋區  551480  23.1373
# 2    新北市三重區  387484  16.3170
# 3    新北市中和區  413590  20.1440
# 4    新北市永和區  222585   5.7138
# 5    新北市新莊區  416524  19.7383
# ..      ...     ...      ...
# 364  金門縣烏坵鄉     685   1.2000
# 365  連江縣南竿鄉    7544  10.4000
# 366  連江縣北竿鄉    2360   9.9000
# 367  連江縣莒光鄉    1624   4.7000
# 368  連江縣東引鄉    1352   3.8000
#
# [368 rows x 3 columns]

# %%
def getState(x):
    return x[:3]

result['縣市']=result['區域別'].map(getState)

# %%
result
# Out:
# 0       區域別   年底人口數     土地面積   縣市
# 1    新北市板橋區  551480  23.1373  新北市
# 2    新北市三重區  387484  16.3170  新北市
# 3    新北市中和區  413590  20.1440  新北市
# 4    新北市永和區  222585   5.7138  新北市
# 5    新北市新莊區  416524  19.7383  新北市
# ..      ...     ...      ...  ...
# 364  金門縣烏坵鄉     685   1.2000  金門縣
# 365  連江縣南竿鄉    7544  10.4000  連江縣
# 366  連江縣北竿鄉    2360   9.9000  連江縣
# 367  連江縣莒光鄉    1624   4.7000  連江縣
# 368  連江縣東引鄉    1352   3.8000  連江縣
#
# [368 rows x 4 columns]

# %%
result=result.set_index('縣市')
result
# Out:
# 0       區域別   年底人口數     土地面積
# 縣市
# 新北市  新北市板橋區  551480  23.1373
# 新北市  新北市三重區  387484  16.3170
# 新北市  新北市中和區  413590  20.1440
# 新北市  新北市永和區  222585   5.7138
# 新北市  新北市新莊區  416524  19.7383
# ..      ...     ...      ...
# 金門縣  金門縣烏坵鄉     685   1.2000
# 連江縣  連江縣南竿鄉    7544  10.4000
# 連江縣  連江縣北竿鄉    2360   9.9000
# 連江縣  連江縣莒光鄉    1624   4.7000
# 連江縣  連江縣東引鄉    1352   3.8000
#
# [368 rows x 3 columns]

# %%
result=result.sum(level='縣市')
result
# Out:
# 0      年底人口數       土地面積
# 縣市
# 新北市  3986689  2052.5667
# 臺北市  2683257   271.7997
# 桃園市  2188017  1220.9540
# 臺中市  2787070  2214.8968
# 臺南市  1886522  2191.6531
# 高雄市  2776912  2951.8524
# 宜蘭縣   456607  2143.6251
# 新竹縣   552169  1427.5369
# 苗栗縣   553807  1820.3149
# 彰化縣  1282458  1074.3960
# 南投縣   501051  4106.4360
# 雲林縣   690373  1290.8326
# 嘉義縣   511182  1903.6367
# 屏東縣   829939  2775.6003
# 臺東縣   219540  3515.2526
# 花蓮縣   329237  4628.5714
# 澎湖縣   104073   126.8641
# 基隆市   371458   132.7589
# 新竹市   441132   104.1526
# 嘉義市   269398    60.0256
# 金門縣   137456   151.6560
# 連江縣    12880    28.8000

# %%
result.sort_values('年底人口數')
# Out:
# 0      年底人口數       土地面積
# 縣市
# 連江縣    12880    28.8000
# 澎湖縣   104073   126.8641
# 金門縣   137456   151.6560
# 臺東縣   219540  3515.2526
# 嘉義市   269398    60.0256
# 花蓮縣   329237  4628.5714
# 基隆市   371458   132.7589
# 新竹市   441132   104.1526
# 宜蘭縣   456607  2143.6251
# 南投縣   501051  4106.4360
# 嘉義縣   511182  1903.6367
# 新竹縣   552169  1427.5369
# 苗栗縣   553807  1820.3149
# 雲林縣   690373  1290.8326
# 屏東縣   829939  2775.6003
# 彰化縣  1282458  1074.3960
# 臺南市  1886522  2191.6531
# 桃園市  2188017  1220.9540
# 臺北市  2683257   271.7997
# 高雄市  2776912  2951.8524
# 臺中市  2787070  2214.8968
# 新北市  3986689  2052.5667

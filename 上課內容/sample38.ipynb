# %%
import pandas as pd
xlsx = pd.ExcelFile('總統.xls')
all=pd.read_excel(xlsx,'中　央')
all
# Out:
#    第14任總統、副總統選舉候選人得票數一覽表     Unnamed: 1     Unnamed: 2     Unnamed: 3  \
# 0                   行政區別      各組候選人得票情形            NaN            NaN
# 1                    NaN  (1)\n朱立倫\n王如玄  (2)\n蔡英文\n陳建仁  (3)\n宋楚瑜\n徐欣瑩
# 2                    NaN            NaN            NaN            NaN
# 3                    NaN            NaN            NaN            NaN
# 4                    總　計        3813365        6894744        1576861
# 5                   　臺北市         546491         757383         153804
# 6                   　新北市         709374        1165888         252486
# 7                   　桃園市         369013         547573         156518
# 8                   　臺中市         430005         793281         218810
# 9                   　臺南市         219196         670608         103432
# 10                  　高雄市         391823         955168         159765
# 11                  　新竹縣          94603         114023          59510
# ...

# %%
all.dtypes
# Out:
# 第14任總統、副總統選舉候選人得票數一覽表    object
# Unnamed: 1               object
# Unnamed: 2               object
# Unnamed: 3               object
# Unnamed: 4               object
# Unnamed: 5               object
# Unnamed: 6               object
# Unnamed: 7               object
# Unnamed: 8               object
# Unnamed: 9               object
# Unnamed: 10              object
# Unnamed: 11              object
# dtype: object

# %%
df=all.iloc[5:,:4]
df
# Out:
#    第14任總統、副總統選舉候選人得票數一覽表 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 5                   　臺北市     546491     757383     153804
# 6                   　新北市     709374    1165888     252486
# 7                   　桃園市     369013     547573     156518
# 8                   　臺中市     430005     793281     218810
# 9                   　臺南市     219196     670608     103432
# 10                  　高雄市     391823     955168     159765
# 11                  　新竹縣      94603     114023      59510
# 12                  　苗栗縣     107779     130461      48788
# 13                  　彰化縣     193117     378736      98807
# 14                  　南投縣      83604     136104      40868
# 15                  　雲林縣      86047     218842      40236
# 16                  　嘉義縣      65425     182913      31469
# 17                  　屏東縣     121291     285297      42768
# 18                  　宜蘭縣      59216     144798      29288
# 19                  　花蓮縣      73894      57198      23751
# ...

# %%
df.columns = ['縣市','朱立倫','蔡英文','宋楚瑜']

# %%
df
# Out:
#       縣市     朱立倫      蔡英文     宋楚瑜
# 5   　臺北市  546491   757383  153804
# 6   　新北市  709374  1165888  252486
# 7   　桃園市  369013   547573  156518
# 8   　臺中市  430005   793281  218810
# 9   　臺南市  219196   670608  103432
# 10  　高雄市  391823   955168  159765
# 11  　新竹縣   94603   114023   59510
# 12  　苗栗縣  107779   130461   48788
# 13  　彰化縣  193117   378736   98807
# 14  　南投縣   83604   136104   40868
# 15  　雲林縣   86047   218842   40236
# 16  　嘉義縣   65425   182913   31469
# 17  　屏東縣  121291   285297   42768
# 18  　宜蘭縣   59216   144798   29288
# 19  　花蓮縣   73894    57198   23751
# 20  　臺東縣   43581    37517   16565
# 21  　澎湖縣   12564    21658    8401
# 22  　基隆市   68357    93402   31955
# 23  　新竹市   71771   113386   36198
# 24  　嘉義市   38822    83143   16926
# 25  　金門縣   24327     6626    5852
# 26  　連江縣    3065      739     664

# %%
df=df.set_index('縣市')

# %%
df.T
# Out:
# 縣市     　臺北市     　新北市    　桃園市    　臺中市    　臺南市    　高雄市    　新竹縣    　苗栗縣    　彰化縣  \
# 朱立倫  546491   709374  369013  430005  219196  391823   94603  107779  193117
# 蔡英文  757383  1165888  547573  793281  670608  955168  114023  130461  378736
# 宋楚瑜  153804   252486  156518  218810  103432  159765   59510   48788   98807
#
# 縣市     　南投縣  ...    　屏東縣    　宜蘭縣   　花蓮縣   　臺東縣   　澎湖縣   　基隆市    　新竹市   　嘉義市  \
# 朱立倫   83604  ...  121291   59216  73894  43581  12564  68357   71771  38822
# 蔡英文  136104  ...  285297  144798  57198  37517  21658  93402  113386  83143
# 宋楚瑜   40868  ...   42768   29288  23751  16565   8401  31955   36198  16926
#
# 縣市    　金門縣  　連江縣
# 朱立倫  24327  3065
# 蔡英文   6626   739
# 宋楚瑜   5852   664
#
# [3 rows x 22 columns]

# %%
df
# Out:
#          朱立倫      蔡英文     宋楚瑜
# 縣市
# 　臺北市  546491   757383  153804
# 　新北市  709374  1165888  252486
# 　桃園市  369013   547573  156518
# 　臺中市  430005   793281  218810
# 　臺南市  219196   670608  103432
# 　高雄市  391823   955168  159765
# 　新竹縣   94603   114023   59510
# 　苗栗縣  107779   130461   48788
# 　彰化縣  193117   378736   98807
# 　南投縣   83604   136104   40868
# 　雲林縣   86047   218842   40236
# 　嘉義縣   65425   182913   31469
# 　屏東縣  121291   285297   42768
# 　宜蘭縣   59216   144798   29288
# 　花蓮縣   73894    57198   23751
# 　臺東縣   43581    37517   16565
# 　澎湖縣   12564    21658    8401
# 　基隆市   68357    93402   31955
# 　新竹市   71771   113386   36198
# 　嘉義市   38822    83143   16926
# 　金門縣   24327     6626    5852
# 　連江縣    3065      739     664

# %%
#總得標
se1=df.sum(axis=0)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
figure, ax1 = plt.subplots()
se1.plot(ax=ax1,kind="bar",color=['b', 'g', 'orange'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib.font_manager import FontProperties
font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)
#window font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)

ax1.set_xticklabels(['朱立倫','蔡英文','宋楚瑜'],fontproperties=font, rotation=360)
ax1.set_xlabel('選舉候選人',fontproperties=font)
ax1.set_yticklabels(['0','1佰','2佰','3佰','4佰','5佰','6佰','7佰'],fontproperties=font)
for p in ax1.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy()
    print(x, y, width, height)
    ax1.annotate('{:.0f}票'.format(height), (x+width/4,height+100000), fontproperties=font)
# Out:
# -0.25 0 0.5 3813365.0
# 0.75 0 0.5 6894744.0
# 1.75 0 0.5 1576861.0

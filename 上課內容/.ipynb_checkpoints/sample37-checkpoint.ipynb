# %%
import numpy as np
import pandas as pd

index = [('台北', 2019), ('台北', 2020),
         ('台中', 2019), ('台中', 2020),
         ('台南', 2019), ('台南', 2020)]

populations = [33871648, 37253956,
               18976457, 19378102,
               20851820, 25145561]

index = pd.MultiIndex.from_tuples(index,names=['縣市','年'])
pop = pd.Series(populations,index=index)
pop
# Out:
# 縣市  年
# 台北  2019    33871648
#     2020    37253956
# 台中  2019    18976457
#     2020    19378102
# 台南  2019    20851820
#     2020    25145561
# dtype: int64

# %%
pop_df=pop.unstack()
pop_df
# Out:
# 年       2019      2020
# 縣市
# 台中  18976457  19378102
# 台北  33871648  37253956
# 台南  20851820  25145561

# %%
pop_df.plot(kind='bar')

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
#mac
font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)
#window
#font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)

# %%
figure, ax1=plt.subplots()
pop_df.plot(ax=ax1,kind='bar',color=['r','g'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax1.set_title('2019,2020城市人口',fontproperties=font)
# Out:
# Text(0.5, 1, '2019,2020城市人口')

# %%
ax1.legend(prop=font)

# %%
ax1.set_xlabel('縣市',fontproperties=font)
# Out:
# Text(0.5, 41.79444444444444, '縣市')

# %%
ax1.set_xticklabels(pop_df.index, fontproperties=font)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-d6b2dc23f4d2> in <module>
# ----> 1 ax1.set_xticklabes(pop_df.index, fontproperties=font)
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_xticklabes'
